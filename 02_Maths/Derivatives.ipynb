# %% [markdown]
# # Slopes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for a non linear line:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Partial Derivatives

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Real Example:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Partial derivative of error respect to age**
#
# **Partial deverivative of error respect to Affordabily**

# %% [markdown]
# ## Practical Exercise

# %% [markdown]
# ![image.png](attachment:image.png)
